# %% [markdown]
# ## OVERVIEW
# *

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\ASUS\Downloads\data science\kerala.csv (2) (2).xls")
df
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...     ...
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2
# 115      KERALA  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5
# 116     KERALA   2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8
# 117      KERALA  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9
#
# ...

# %% [markdown]
# ### check for errors

# %%
df.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', ' ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBDIVISION       118 non-null    object
#  1   YEAR              118 non-null    int64
#  2   JAN               118 non-null    float64
#  3   FEB               118 non-null    float64
#  4   MAR               118 non-null    float64
#  5   APR               118 non-null    float64
#  6   MAY               118 non-null    float64
#  7   JUN               118 non-null    float64
#  8   JUL               118 non-null    float64
#  9   AUG               118 non-null    float64
#  10  SEP               118 non-null    float64
#  11  OCT               118 non-null    float64
#  12  NOV               118 non-null    float64
#  13  DEC               118 non-null    float64
#  14   ANNUAL RAINFALL  118 non-null    float64
#  15  FLOODS            118 non-null    object
# ...

# %%
df.size
# Out:
# 1888

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# SUBDIVISION         0
# YEAR                0
# JAN                 0
# FEB                 0
# MAR                 0
# APR                 0
# MAY                 0
# JUN                 0
# JUL                 0
# AUG                 0
# SEP                 0
# OCT                 0
# NOV                 0
# DEC                 0
#  ANNUAL RAINFALL    0
# FLOODS              0
# dtype: int64

# %%
df.shape
# Out:
# (118, 16)

# %%
df.dtypes
# Out:
# SUBDIVISION          object
# YEAR                  int64
# JAN                 float64
# FEB                 float64
# MAR                 float64
# APR                 float64
# MAY                 float64
# JUN                 float64
# JUL                 float64
# AUG                 float64
# SEP                 float64
# OCT                 float64
# NOV                 float64
# DEC                 float64
#  ANNUAL RAINFALL    float64
# FLOODS               object
# dtype: object

# %%
df['YEAR'].unique()
# Out:
# array([1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911,
#        1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922,
#        1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933,
#        1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944,
#        1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955,
#        1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966,
#        1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#        1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#        1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], dtype=int64)

# %%
df['JAN'].unique()
# Out:
# array([28.7,  6.7,  3.2, 23.7,  1.2, 26.7, 18.8,  8. , 54.1,  2.7,  3. ,
#         1.9,  3.1,  0.7, 16.9,  0. ,  2.9, 42.9, 43. , 35.2, 30.5, 24.7,
#        19.3,  4.1, 28.6, 12.7, 12.8, 10.8,  3.3,  0.1,  1. , 74.5, 23.9,
#         6.5,  0.3, 13.6,  0.6, 15.9,  2.4, 83.5,  6.4,  4.4,  1.8, 22.2,
#         6.6,  5.2, 13.1, 23.5,  4.2,  7.9,  9.4, 13.7, 28.4, 30.2,  1.1,
#         9.1, 14.3,  7.3, 12.9, 31.6,  2.6,  1.6,  7. ,  0.2, 36.8, 61.2,
#         5.6,  0.8, 10.3, 14.9, 10.9, 24.3,  2.8,  2.1,  6. , 11.7, 16.5,
#         4.7, 19.8,  8.1,  0.5, 18.6, 20.5,  7.4,  3.9,  4.6, 29.1])

# %% [markdown]
# ### Analysing data

# %%
df.describe().T
# Out:
#                   count         mean         std     min       25%      50%  \
# YEAR              118.0  1959.500000   34.207699  1901.0  1930.250  1959.50
# JAN               118.0    12.218644   15.473766     0.0     2.175     5.80
# FEB               118.0    15.633898   16.406290     0.0     4.700     8.35
# MAR               118.0    36.670339   30.063862     0.1    18.100    28.40
# APR               118.0   110.330508   44.633452    13.1    74.350   110.40
# MAY               118.0   228.644915  147.548778    53.4   125.050   184.60
# JUN               118.0   651.617797  186.181363   196.8   535.550   625.60
# JUL               118.0   698.220339  228.988966   167.5   533.200   691.65
# AUG               118.0   430.369492  181.980463   178.6   316.725   386.25
# SEP               118.0   246.207627  121.901131    41.3   155.425   223.55
# OCT               118.0   293.207627   93.705253    68.5   222.125   284.30
# ...

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x=df['YEAR'],y=df[' ANNUAL RAINFALL'],marker='o',color='indigo')
plt.title('Annual rainfall')
plt.show()

# %% [markdown]
# ### Kerala had the highest rainfall in 2018

# %%
a=df[df['YEAR']==2018].squeeze()
months=['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']
plt.figure(figsize=(10,5))
plt.bar(months,a[months],color='violet',edgecolor='black')
plt.title('rainfall of each month in 2018')
plt.xlabel('months')
plt.ylabel('rainfall recieved')
plt.show()

# %% [markdown]
# ### In 2018 Kerala recieved the highest rainfall in the month of august

# %%
plt.figure(figsize=(15,7))
df['FLOODS'].value_counts().plot(kind='pie',colors=['gold','silver'],autopct='%1.1f%%',startangle=90)
plt.title('flood occured')
plt.show()

# %% [markdown]
# ### From 1901 to 2018 50% of time kerala had flood

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, hue='FLOODS',y=' ANNUAL RAINFALL',palette='inferno')
plt.title('rainfall recieved annually during flood and non flood years')
plt.show()

# %% [markdown]
# ### When there is an annual rainfall >3300 ,its more likely to have a flood

# %%
monthly_avg = df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 
                  'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
plt.figure(figsize=(14, 6))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values,color="navy")
plt.title('Average Monthly Rainfall in Kerala (1901–2018)', fontsize=16)
plt.xlabel('Month')
plt.ylabel('Average Rainfall (mm)')
plt.show()

# %% [markdown]
# ### Data indicates that the july month receive the highest rainfall

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='YEAR', y='JUN', color='teal', marker='o')
plt.title('July Rainfall Trend Over the Years in Kerala', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Rainfall in June (mm)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### july month recieved highest rainfall in 1990

# %%
df['Decade'] = (df['YEAR'] // 10) * 10
plt.figure(figsize=(12, 6))
sns.countplot(x='Decade', hue='FLOODS', data=df, palette='inferno')
plt.title('Flood Occurrences by Decade', fontsize=16)
plt.xlabel('Decade')
plt.ylabel('Count')
plt.legend(title='Floods')
plt.show()

# %% [markdown]
# ### 1940 to 1950 decade had the highest flood years and 1980 to 1990 had the least flood years

# %%
df['Monsoon_Rainfall'] = df[['JUN', 'JUL', 'AUG', 'SEP']].sum(axis=1)
df['Non_Monsoon_Rainfall'] = df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'OCT', 'NOV', 'DEC']].sum(axis=1)

# %%
plt.figure(figsize=(30,10))
df[['YEAR', 'Monsoon_Rainfall', 'Non_Monsoon_Rainfall']].set_index('YEAR').plot(kind='line')
plt.title('Monsoon vs Non-Monsoon Rainfall in Kerala', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Rainfall (mm)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Kerala depends upon the monsoon months for rain as it recieves highest rainfall during monsoon

# %% [markdown]
# ## CONCLUSION
# * Kerala had the highest rainfall in 2018
# * In 2018 Kerala recieved the highest rainfall in the month of august
# * From 1901 to 2018 50% of time kerala had flood
# * When there is an annual rainfall >3300 ,its more likely to have a flood
# * 1940 to 1950 decade had the highest flood years and 1980 to 1990 had the least flood years
# * Kerala depends upon the monsoon months for rain as it recieves highest rainfall during monsoon
